# %% [markdown]
# ### 图片灰度处理

# %% [markdown]
# 三种方法

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

img = plt.imread('./IMG_20150913_115108.jpg')
plt.imshow(img,cmap = plt.cm.gray)

# %%
img.shape
# Out:
# (2448, 3264, 3)

# %%
gray = img.max(axis = -1)
plt.imshow(gray,cmap = plt.cm.gray)

# %%
gray.shape
# Out:
# (2448, 3264)

# %%
# 红绿蓝 0.33,0.33,0.33
gray = img.mean(axis = 2)
plt.imshow(gray,cmap = plt.cm.gray)

# %%
# 加权平均值 红绿蓝
# 0.299,0.587,0.114

w = np.array([0.299,0.587,0.114])

gray = img.dot(w)
gray.shape
# Out:
# (2448, 3264)

# %%
plt.imshow(gray,cmap = plt.cm.gray)

# %% [markdown]
# # matplotlib

# %% [markdown]
# ## 目录
# + 一、【重点】Matplotlib基础知识
#
# + 二、设置plot的风格和样式
#     + 1、【重点】点和线的样式
#     + 2、X、Y轴坐标刻度
#
#
# + 三、2D图形
#     + 1、示例
#     + 2、【重点】直方图
#     + 3、【重点】条形图
#     + 4、【重点】饼图
#     + 5、【重点】散点图
#
# =============以上为重点=================
#
# #### 下面的自学
# + 四、图形内的文字、注释、箭头
#     + 1、图形内的文字
#     + 2、注释
#     + 3、箭头
#
# + 五、3D图
#     + 1、曲面图

# %% [markdown]
# ## 一、Matplotlib基础知识

# %% [markdown]
# Matplotlib中的基本图表包括的元素
# + x轴和y轴
# 水平和垂直的轴线
#
#
# + x轴和y轴刻度
# 刻度标示坐标轴的分隔，包括最小刻度和最大刻度
#
#
# + x轴和y轴刻度标签
# 表示特定坐标轴的值
#
#
# + 绘图区域
# 实际绘图的区域

# %% [markdown]
# ### 只含单一曲线的图

# %%
x = np.linspace(0,2*np.pi)

y = np.sin(x)

plt.plot(x,y)

# %% [markdown]
# ### 包含多个曲线的图

# %% [markdown]
# 1、可以使用多个plot函数（推荐），在一个图中绘制多个曲线

# %%
y2 = np.cos(x)

# %%
plt.plot(x,y)
plt.plot(x,y2)

# %% [markdown]
# 2、也可以在一个plot函数中传入多对X,Y值，在一个图中绘制多个曲线

# %%
plt.plot(x,y,x,y2)
# Out:
# [<matplotlib.lines.Line2D at 0x18f47f38940>,
#  <matplotlib.lines.Line2D at 0x18f47f38b00>]

# %%
plt.plot(y)

# %%
plt.plot(y,'o')

# %%
plt.plot(y,marker = 'o')

# %% [markdown]
# ### 网格线
# 绘制正选余弦

# %%
plt.plot(x,y)

plt.grid()

# %% [markdown]
# 使用plt.grid(True)方法为图添加网格线

# %% [markdown]
# 设置grid参数（参数与plot函数相同），使用plt面向对象的方法，创建多个子图显示不同网格线
# ![](1.PNG)
#
# - lw代表linewidth，线的粗细
# - alpha表示线的明暗程度
# - color代表颜色

# %%
# 1行，3列
plt.figure(figsize=(12,3))
ax = plt.subplot(1,3,1)
ax.plot(x,y)
ax.grid()

ax = plt.subplot(1,3,2)
ax.plot(x,y)
ax.grid(color = 'red',alpha =0.2 )

ax = plt.subplot(1,3,3)
ax.plot(x,y)
'''linestyle or ls: ['solid' | 'dashed', 'dashdot', 'dotted' | 
(offset, on-off-dash-seq) | ``'-'`` | ``'--'`` | ``'-.'`` | ``':'`` | ``'None'`` | ``' '`` | ``''``]'''
ax.grid(color = 'green',linestyle = 'dashed')

# %% [markdown]
# ### 坐标轴界限

# %% [markdown]
# #### axis方法
# 如果axis方法没有任何参数，则返回当前坐标轴的上下限axis(xmin =,ymax = )

# %%
plt.plot(x,y)
plt.axis([-2,8,-1,1])
# Out:
# [-2, 8, -1, 1]

# %%
line = plt.plot(x,y)
line[0].set_color('red')

# %%
line, = plt.plot(x,y)
line.set_color('green')

# %% [markdown]
# ##### plt.axis('xxx') 'tight'、'off'、'equal'……
#
# 设置坐标轴类型
# 关闭坐标轴
# ![](2.png)

# %%
angle = np.linspace(0,2*np.pi,200)

x = np.sin(angle)
y = np.cos(angle)

# plt.figure(figsize=(5,5))

plt.plot(x,y)

# plt.axis([-1.5,1.5,-1,1])

plt.axis('equal')
# Out:
# (-1.099965731583572, 1.099965731583572, -1.09986915899354, 1.0999937694758828)

# %% [markdown]
# #### xlim方法和ylim方法
#
# 除了plt.axis方法，还可以通过xlim，ylim方法设置坐标轴范围

# %%
plt.plot(x,y)

plt.xlim([-1.5,1.5])

plt.ylim([-1,1])
# Out:
# (-1, 1)

# %% [markdown]
# ### 坐标轴标签
# xlabel方法和ylabel方法
# plt.ylabel('y = x^2 + 5',rotation = 60)旋转

# %%
# 全局的字体设置
from matplotlib import rcParams

# %%
rcParams['font.sans-serif'] = 'KaiTi'

# %%
rcParams['axes.unicode_minus'] = False

# %%
plt.plot(x,y)

plt.axis('equal')

plt.xlabel('X',fontsize = 20,color = 'red')

plt.ylabel('X**2 + Y**2 = 1',fontsize = 20,rotation = -60)

plt.title('Cicle圆',fontsize = 30)
# Out:
# Text(0.5,1,'Cicle圆')

# %% [markdown]
# ### 标题
# title方法

# %% [markdown]
# ### 图例

# %% [markdown]
# #### legend方法
#
# 两种传参方法：
# - 【推荐使用】在plot函数中增加label参数
# - 在legend方法中传入字符串列表
# ![](3.png)

# %%
x = np.linspace(0,2*np.pi)
plt.plot(x,np.sin(x),x,np.cos(x))
plt.legend(['正弦波','余弦波'])

# %% [markdown]
# label参数为'_xxx'，则图例中不显示
# plt.plot(x, x*1.5, label = '_xxx')

# %% [markdown]
# ### loc参数

# %% [markdown]
# | 字符串       | 数值      | 字符串   |  数值 |
# | :-------------: |:-----------:| :-----:|  :-----:|
# | best        |  0        | center left   |   6 |
# | upper right    | 1        | center right  |   7  |
# | upper left    |  2        | lower center  |   8  |
# | lower left    |  3        | upper center  |   9 |
# | lower right   |  4        | center      |   10 |
# | right       |  5        |

# %%
x = np.linspace(0,2*np.pi)
plt.plot(x,np.sin(x),x,np.cos(x))
plt.legend(['正弦波','余弦波'],loc = 'right')

# %% [markdown]
# loc参数可以是2元素的元组，表示图例左下角的坐标

# %%
x = np.linspace(0,2*np.pi)
plt.plot(x,np.sin(x),x,np.cos(x))
plt.legend(['正弦波','余弦波'],loc = (0,1.05))

# %% [markdown]
# 图例也可以超过图的界限loc = (-0.1,0.9)

# %% [markdown]
# ### ncol参数
# ncol控制图例中有几列

# %%
x = np.linspace(0,2*np.pi)
plt.plot(x,np.sin(x),x,np.cos(x))
plt.legend(['正弦波','余弦波'],loc = (0,1.05),ncol = 2)

# %% [markdown]
# ### linestyle、color、marker
# 修改线条样式
# ![](4.png)

# %%
plt.plot(x,np.sin(x),color = 'red',marker = '*',linestyle  = '--')

plt.savefig('./fig2.png',dpi = 500,facecolor = 'green')

# %%
ax = plt.subplot(1,1,1,facecolor = 'green')

ax.plot(x,np.sin(x),color = 'red',marker = '*',linestyle  = '--')

plt.savefig('./fig3.pdf',dpi = 500,facecolor = 'green')

# %% [markdown]
# ### 保存图片

# %% [markdown]
# figure.savefig的选项
# + filename
# 含有文件路径的字符串或Python的文件型对象。图像格式由文件扩展名推断得出，例如，.pdf推断出PDF，.png推断出PNG
# （“png”、“pdf”、“svg”、“ps”、“eps”……）
# + dpi
# 图像分辨率（每英寸点数），默认为100
# + facecolor
# 图像的背景色，默认为“w”（白色）

# %% [markdown]
# ## 二、设置plot的风格和样式
# plot语句中支持除X,Y以外的参数，以字符串形式存在，来控制颜色、线型、点型等要素，语法形式为：
# plt.plot(X, Y, 'format', ...)

# %% [markdown]
# ### 点和线的样式

# %% [markdown]
# #### 颜色
# 参数color或c

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,2*np.pi,50)

# %% [markdown]
# ##### 颜色值的方式
# + 别名
#     + color='r'
#
#
#
# + 合法的HTML颜色名
#     + color = 'red'
#
# | 颜色       | 别名      | HTML颜色名  | 颜色   |  别名 |HTML颜色名|
# | :-------------: |:---------:|:-----------:| :------:|  :-----:| :-----:|
# | 蓝色        | b       | blue      | 绿色   |  g   |  green  |
# | 红色        | r       | red      | 黄色    |  y   |  yellow |
# | 青色        | c       | cyan      | 黑色   |  k   |  black  |
# | 洋红色      | m        | magenta    | 白色   |  w   |  white  |
#
#
#
#
#
#
# + HTML十六进制字符串
#     + color = '#eeefff'
#
#
#
#
# + 归一化到[0, 1]的RGB元组
#     + color = (0.3, 0.3, 0.4)

# %%
plt.plot(x,np.sin(x),color = 'orange')

# %%
0X00
# Out:
# 0

# %%
0Xffffff
# Out:
# 16777215

# %%
plt.plot(x,np.sin(x),color = '#000000')

# %%
plt.plot(x,np.sin(x),c = 'blue')

# %%
plt.plot(x,np.sin(x),c = np.random.rand(3))

# %% [markdown]
# ##### 透明度
# alpha参数

# %%
plt.plot(x,np.sin(x),alpha = 0.2)

# %% [markdown]
# ##### 背景色
# 设置背景色，通过plt.subplot()方法传入facecolor参数，来设置坐标轴的背景色

# %%
ax = plt.subplot(1,1,1,facecolor = 'green')

ax.plot(x,np.sin(x),color = 'red')

# %% [markdown]
# #### 线型
# 参数linestyle或ls

# %% [markdown]
# | 线条风格     | 描述      | 线条风格 |  描述 |
# | :-------------: |:------------:| :----:|  :-----:|
# | '-'        | 实线     | ':'     |  虚线 |
# | '--'       | 破折线    | 'steps'  |  阶梯线 |
# | '-.'       | 点划线    | 'None' / '，' |  什么都不画 |

# %%
plt.plot(x,np.sin(x),linestyle = 'steps')

# %%
plt.plot(x,np.sin(x),ls = 'steps')

# %% [markdown]
# ##### 线宽
# linewidth或lw参数

# %%
plt.plot(x,np.sin(x),ls = 'steps',lw = 5)

# %% [markdown]
# ##### 不同宽度的破折线
# dashes参数
# 设置破折号序列各段的宽度
# ![](5.png)

# %%
# dashes = [线宽，间距，线宽，间距，……]
plt.plot(x,np.sin(x),dashes = [1,2,5,3,2,5])

# %% [markdown]
# #### 点型
# marker参数

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | '1'         | 一角朝下的三脚架      | '3'     |  一角朝左的三脚架 |
# | '2'         | 一角朝上的三脚架      | '4'     |  一角朝右的三脚架 |

# %%
x.shape
# Out:
# (50,)

# %%
plt.figure(figsize=(12,9))
plt.plot(x,np.sin(x),marker = '4',markersize = 20)

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | 's'         | 正方形   | 'p'   | 五边形     |
# | 'h'         | 六边形1    | 'H'     | 六边形2    |
# | '8'         | 八边形     |

# %%
x = np.linspace(0,2*np.pi,20)
plt.figure(figsize=(12,9))
plt.plot(x,np.sin(x),marker = 'h',markersize = 20)

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | '.'     |  点 | 'x'   | X   |
# | '\*'    |  星号  | '+'         | 加号       |
# | ','         | 像素       |

# %%
x = np.linspace(0,2*np.pi,20)
plt.figure(figsize=(12,9))
plt.plot(x,np.sin(x),marker = '*',markersize = 20)

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | 'o'         | 圆圈      | 'D'         | 菱形      |
# | 'd'    |  小菱形  |'','None',' ',None| 无       |

# %%
x = np.linspace(0,2*np.pi,20)
plt.figure(figsize=(12,9))
plt.plot(x,np.sin(x),marker = 'd',markersize = 20)

# %% [markdown]
# | 标记     | 描述     | 标记   |  描述 |
# | :--------: |:----------:| :------:| :----:|
# | '\_'     |  水平线    | '&#124;'     |  水平线
# ![](6.png)

# %%
x = np.linspace(0,2*np.pi,20)
plt.figure(figsize=(12,9))
plt.plot(x,np.sin(x),marker = '_',markersize = 20)

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | 'v'         | 一角朝下的三角形 | '<'     |  一角朝左的三角形 |
# | '^'         | 一角朝上的三角形 | '>'     |  一角朝右的三角形 |

# %% [markdown]
# #### 多参数连用
# 颜色、点型、线型

# %% [markdown]
# #### 更多点和线的设置

# %% [markdown]
# | 参数        | 描述       | 参数       |  描述   |
# | :-------------: |:-----------:| :-------------:|  :------:|
# | color或c      | 线的颜色   | linestyle或ls  |  线型   |
# | linewidth或lw   | 线宽     | marker       |  点型  |
# | markeredgecolor  | 点边缘的颜色 | markeredgewidth | 点边缘的宽度 |
# | markerfacecolor  | 点内部的颜色 | markersize    |  点的大小    |
# ![](7.png)

# %%
plt.plot(x,np.sin(x),c = 'red',marker = '*',markersize = 20,markerfacecolor = 'g',markeredgecolor = 'blue')

# %% [markdown]
# #### 在一条语句中为多个曲线进行设置

# %% [markdown]
# ##### 多个曲线同一设置
# 属性名声明
#
# plt.plot(x1, y1, x2, y2, fmt, ...)

# %%
plt.plot(x,np.sin(x),x,np.cos(x),color = 'r',alpha = 0.5)
# Out:
# [<matplotlib.lines.Line2D at 0x2838b778748>,
#  <matplotlib.lines.Line2D at 0x2838b778908>]

# %% [markdown]
# ##### 多个曲线不同设置
# 多个都进行设置时，无需声明属性
# plt.plot(x1, y1, fmt1, x2, y2, fmt2, ...)

# %%
plt.plot(x,np.sin(x),'r--o',x,np.cos(x),'g:*')
# Out:
# [<matplotlib.lines.Line2D at 0x2838baab550>,
#  <matplotlib.lines.Line2D at 0x2838baab6d8>]

# %% [markdown]
# #### 三种设置方式

# %% [markdown]
# ##### 向方法传入关键字参数

# %%
plt.plot(x,np.sin(x),color = 'red')

# %% [markdown]
# ##### 对实例使用一系列的setter方法

# %%
line, = plt.plot(x,np.sin(x))

line.set_color('#ff00ff')

line.set_ls('--')

# %% [markdown]
# ##### 使用setp()方法

# %%
line1,line2 = plt.plot(x,np.sin(x),x,np.cos(x))

# plt 是模块方法
plt.setp(line1,color = 'red',ls = 'steps')
# Out:
# [None, None]

# %% [markdown]
# ### X、Y轴坐标刻度
# xticks()和yticks()方法
# ![](8.png)

# %%
plt.plot(x,np.sin(x))
_ = plt.xticks(np.arange(7),list('abcdefg'))
_ = plt.yticks([-1,0,1],['min',0,'max'],color = 'r',fontsize = 20,rotation = -60)

# %% [markdown]
# #### 面向对象方法
# set_xticks、set_yticks、set_xticklabels、set_yticklabels方法

# %% [markdown]
# #### 正弦余弦
# LaTex语法，用$\pi$等表达式在图表上写上希腊字母
# ![](9.png)

# %%
plt.figure(figsize=(12,9))
plt.plot(x,np.sin(x))
_ = plt.xticks(np.arange(0,2*np.pi+0.01,np.pi/2),['$\\theta$','$\pi/2$','$\pi$','$3\pi/2$','$2\pi$'],fontsize = 30)
_ = plt.yticks([-1,0,1],['min',0,'max'],color = 'r',fontsize = 20,rotation = -60)

# %% [markdown]
# ## 三、2D图形

# %% [markdown]
# ### 直方图
#
# 【直方图的参数只有一个x！！！不像条形图需要传入x,y】
#
# hist()的参数
# + bins
# 可以是一个bin数量的整数值，也可以是表示bin的一个序列。默认值为10
# + normed
# 如果值为True，直方图的值将进行归一化处理，形成概率密度，默认值为False
# + color
# 指定直方图的颜色。可以是单一颜色值或颜色的序列。如果指定了多个数据集合，颜色序列将会设置为相同的顺序。如果未指定，将会使用一个默认的线条颜色
# + orientation
# 通过设置orientation为horizontal创建水平直方图。默认值为vertical

# %%
wind = np.load('./Ravenna_wind.npy')
wind
# Out:
# array([ 10.    ,  20.    ,  40.    ,  90.    ,  87.    ,  79.    ,
#         70.    ,  80.    ,  90.    ,  90.    , 105.    , 100.    ,
#        110.    , 116.504 , 145.001 , 145.001 , 145.001 , 155.503 ,
#        155.503 , 155.503 , 190.    , 126.501 , 250.    ,  99.0009,
#        330.003 ,  20.    ,  70.    ,  70.    ,  10.    ,  80.    ,
#        126.    , 100.    , 135.    , 130.    , 160.    , 130.501 ,
#        190.    , 180.    , 193.502 , 193.502 , 224.004 , 224.004 ,
#        224.004 , 180.    , 190.    , 254.001 , 257.503 , 190.    ,
#        159.5   , 100.    ,  80.    ,  90.    ,  80.    ,  80.    ,
#         90.    ,  90.    ,  90.    ,  97.    ,  89.    ,  88.0147,
#        107.004 , 107.004 , 132.503 , 132.503 , 132.503 , 251.    ])

# %%
# rwidth  rate 比例
data = plt.hist(wind,bins = 8,range = [0,360],color = np.random.rand(3),rwidth = 0.5)

# %% [markdown]
# ### 条形图
#
# 【条形图有两个参数x,y！】
#
# bar()、barh()

# %%
y =data[0]
x = data[1]
display(x,y)
# Out:
# array([  0.,  45.,  90., 135., 180., 225., 270., 315., 360.])
# array([ 5., 12., 24.,  9., 11.,  4.,  0.,  1.])

# %%
plt.bar(x[:-1],y,width = 22.5,align = 'edge',color = np.random.rand(8,3))
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# #### 水平条形图
# barh()

# %% [markdown]
# ### 饼图
#
# 【饼图也只有一个参数x！】
#
# pie()
# 饼图适合展示各部分占总体的比例，条形图适合比较各部分的大小

# %% [markdown]
# 普通各部分占满饼图

# %%
from matplotlib import rcParams

# %%
# 设置字体大小，全局
rcParams['font.size'] = 20

# %%
plt.figure(figsize=(9,9))
_ = plt.pie([0.277,0.423,0.3],explode=[0,0.2,0],labels = ['cat','dog','pig'],autopct='%0.1f%%',shadow=True)
_ = plt.axis('equal')

# %% [markdown]
# 普通未占满饼图

# %% [markdown]
# 饼图阴影、分裂等属性设置
# #labels参数设置每一块的标签；labeldistance参数设置标签距离圆心的距离（比例值）
# #autopct参数设置比例值的显示格式(%1.1f%%)；pctdistance参数设置比例值文字距离圆心的距离
# #explode参数设置每一块顶点距圆形的长度（比例值）；colors参数设置每一块的颜色；
# #shadow参数为布尔值，设置是否绘制阴影

# %% [markdown]
# startangle设置旋转角度

# %% [markdown]
# ### 散点图
#
# 【散点图需要两个参数x,y，但此时x不是表示x轴的刻度，而是每个点的横坐标！】
#
# scatter()
# ![](10.png)

# %%
plt.scatter(np.random.randn(1000),np.random.randn(1000),color = np.random.rand(1000,3),marker = 'd')

# %% [markdown]
# ## <font color = red>四、图形内的文字、注释、箭头(自学)</font>

# %% [markdown]
# 控制文字属性的方法:
#
#
# | Pyplot函数     | API方法                | 描述                     |
# | :-------------: |:------------------------------:| :---------------------------------:|
# | text()       |  mpl.axes.Axes.text()       | 在Axes对象的任意位置添加文字     |
# | xlabel()      |  mpl.axes.Axes.set_xlabel()   | 为X轴添加标签               |
# | ylabel()      |  mpl.axes.Axes.set_ylabel()   | 为Y轴添加标签               |
# | title()       | mpl.axes.Axes.set_title()   |  为Axes对象添加标题            |
# | legend()      | mpl.axes.Axes.legend()      |  为Axes对象添加图例            |
# | figtext()     |  mpl.figure.Figure.text()    |  在Figure对象的任意位置添加文字    |
# | suptitle()     | mpl.figure.Figure.suptitle() |  为Figure对象添加中心化的标题     |
# | annnotate()    |  mpl.axes.Axes.annotate()    |  为Axes对象添加注释（箭头可选）    |
#
#
# 所有的方法会返回一个matplotlib.text.Text对象

# %% [markdown]
# ### 图形内的文字
# text()
# ![](14.png)

# %% [markdown]
# 使用figtext()

# %%
x = np.linspace(0,2*np.pi,50)
plt.plot(x,np.sin(x))
# text中表示刻度
# plt.text(0,0,s = 'sin(0) = 0')
# figtext()代表相对坐标
plt.figtext(0.2,0.5,s = 'sin(0) = 0')
# Out:
# Text(0.2,0.5,'sin(0) = 0')

# %%
rcParams['font.sans-serif'] = 'KaiTi'

# %%
rcParams['axes.unicode_minus'] = False

# %%
ax = plt.subplot(1,2,1)
ax.plot(x,np.sin(x))
ax.set_title('sin')
ax = plt.subplot(1,2,2)
ax.plot(x,np.cos(x))

ax.set_title('Cos')

plt.suptitle('正弦波和余弦波',x = 0.5,y = 1.1)
# Out:
# Text(0.5,1.1,'正弦波和余弦波')

# %% [markdown]
# ### 注释
# annotate()
# xy参数设置箭头指示的位置，xytext参数设置注释文字的位置
# arrowprops参数以字典的形式设置箭头的样式
# width参数设置箭头长方形部分的宽度，headlength参数设置箭头尖端的长度，
# headwidth参数设置箭头尖端底部的宽度，
# facecolor设置箭头颜色
# shrink参数设置箭头顶点、尾部与指示点、注释文字的距离（比例值）
# ![](15.png)

# %%
x  = np.arange(15)

y = np.random.randint(10,15,size = 15)

y[6] = 30

plt.plot(x,y)

plt.axis([-2,15,9,35])
'''    width        the width of the arrow in points
    headwidth    the width of the base of the arrow head in points
    headlength   the length of the arrow head in points
    shrink       fraction of total length to 'shrink' from both ends'''
plt.annotate(s = 'this point\nvery well',xy = (6,30),xytext = (8,32),arrowprops={'width':10,'headwidth':15,'headlength':10,'shrink':0.2})
# Out:
# Text(8,32,'this point\nvery well')

# %% [markdown]
# 练习
# 三个随机正太分布数据
# ![](16.png)
# 设置图例
# bbox_to_anchor,ncol mode,borderaxespad
# 设置注解 arrowstyle

# %% [markdown]
# ### 箭头
# 箭头的样式，没必要记

# %%
plt.figure(figsize=(12,9))
plt.axis([0, 10, 0, 20]);
arrstyles = ['-', '->', '-[', '<-', '<->', 'fancy', 'simple', 'wedge']
for i, style in enumerate(arrstyles):
    plt.annotate(style, xytext=(1, 2+2*i), xy=(4, 1+2*i), arrowprops=dict(arrowstyle=style));

connstyles=["arc", "arc,angleA=10,armA=30,rad=30", "arc3,rad=.2", "arc3,rad=-.2", "angle", "angle3"]
for i, style in enumerate(connstyles):
    plt.annotate(style, xytext=(6, 2+2*i), xy=(8, 1+2*i), arrowprops=dict(arrowstyle='->', connectionstyle=style));
plt.show()

# %% [markdown]
# ## <font color = red>五、3D图(自学)</font>

# %% [markdown]
# #### 曲面图
# ![](11.png)

# %% [markdown]
# 导包
# from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %% [markdown]
# 生成数据

# %%
x = np.linspace(-2,2,100)

y = np.linspace(-2,2,100)

z = (x**2 + y**2)**0.5


fig = plt.figure(figsize=(12,9))

axes3D = Axes3D(fig)

axes3D.plot(x,y,z)


X,Y = np.meshgrid(x,y)

Z = (X**2 + Y**2)**0.5

axes3D.plot_surface(X,Y,Z)

# %%
a = np.linspace(-2,2,100)
b = np.linspace(-2,2,100)

A,B = np.meshgrid(a,b)
plt.scatter(A,B)

# %%
plt.plot(x,y)

# %% [markdown]
# 绘制图形

# %%
x
# Out:
# array([  0.,  45.,  90., 135., 180., 225., 270., 315., 360.])

# %%
plt.figure(figsize=(8,8))
plt.axes(polar = True)
# x 0,2*n.pi
x = np.arange(0,2*np.pi,np.pi/4)
plt.bar(x,y,width = np.pi/4,color = np.random.rand(8,3))
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# ## <font color = red>玫瑰图/极坐标条形图(自学)</font>
# ![](13.png)

# %% [markdown]
# 创建极坐标条形图

# %% [markdown]
# 使用np.histogram计算一组数据的直方图
